# %%
import pandas as pd

import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='GFURuYfs9uLRAie_Ty6_N0ixUJhw6svgVbRA7VtpsppH',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.eu-de.cloud-object-storage.appdomain.cloud')

bucket = 'waterquality-donotdelete-pr-h0r0jxyglqzd3n'
object_key = 'Water Quality Testing (1).csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df= pd.read_csv(body)
df
# Out:
#       Sample ID  Temperature (°C)  Turbidity (NTU)  Dissolved Oxygen (mg/L)  \
# 0           1.0              23.1              4.5                      7.8
# 1           2.0              22.3              5.1                      6.2
# 2           3.0              21.5              3.9                      8.3
# 3           4.0              22.9              3.2                      9.5
# 4           5.0              20.7              3.8                      8.1
# ...         ...               ...              ...                      ...
# 3271        NaN               NaN              NaN                      NaN
# 3272        NaN               NaN              NaN                      NaN
# 3273        NaN               NaN              NaN                      NaN
# 3274        NaN               NaN              NaN                      NaN
# 3275        NaN               NaN              NaN                      NaN
#
# ...

# %% [markdown]
# ## We can come to a conclusion the full CSVfile

# %%
print(df.shape)
# Out:
# (3276, 15)

# %% [markdown]
# ## We can come to a conclusion that in csv file how many rowsand columns are their in CSVfile

# %%
print(df.columns)
# Out:
# Index(['Sample ID', 'Temperature (°C)', 'Turbidity (NTU)',
#        'Dissolved Oxygen (mg/L)', 'Conductivity (µS/cm)', 'ph', 'Hardness',
#        'Solids', 'Chloramines', 'Sulfate', 'Conductivity', 'Organic_carbon',
#        'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %% [markdown]
# ## We can come to a conclusion that in CSV File that how many  column are there

# %%
print(df.dtypes)
# Out:
# Sample ID                  float64
# Temperature (°C)           float64
# Turbidity (NTU)            float64
# Dissolved Oxygen (mg/L)    float64
# Conductivity (µS/cm)       float64
# ph                         float64
# Hardness                   float64
# Solids                     float64
# Chloramines                float64
# Sulfate                    float64
# Conductivity               float64
# Organic_carbon             float64
# Trihalomethanes            float64
# Turbidity                  float64
# Potability                   int64
# dtype: object

# %% [markdown]
# ## We can come to a conclusion that in CSV File that what type of datatype in this file

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Sample ID                500 non-null    float64
#  1   Temperature (°C)         500 non-null    float64
#  2   Turbidity (NTU)          500 non-null    float64
#  3   Dissolved Oxygen (mg/L)  500 non-null    float64
#  4   Conductivity (µS/cm)     500 non-null    float64
#  5   ph                       2785 non-null   float64
#  6   Hardness                 3276 non-null   float64
#  7   Solids                   3276 non-null   float64
#  8   Chloramines              3276 non-null   float64
#  9   Sulfate                  2495 non-null   float64
#  10  Conductivity             3276 non-null   float64
#  11  Organic_carbon           3276 non-null   float64
#  12  Trihalomethanes          3114 non-null   float64
# ...

# %% [markdown]
# ## We can come to a conclusion that in CSV File that it give full information about the file like storage,datatypes etc.

# %%
print(df.head(n=10))
# Out:
#    Sample ID  Temperature (°C)  Turbidity (NTU)  Dissolved Oxygen (mg/L)  \
# 0        1.0              23.1              4.5                      7.8
# 1        2.0              22.3              5.1                      6.2
# 2        3.0              21.5              3.9                      8.3
# 3        4.0              22.9              3.2                      9.5
# 4        5.0              20.7              3.8                      8.1
# 5        6.0              23.6              4.6                      7.2
# 6        7.0              21.2              4.2                      8.8
# 7        8.0              22.1              3.7                      6.9
# 8        9.0              20.4              4.1                      8.4
# 9       10.0              22.7              4.8                      7.5
#
#    Conductivity (µS/cm)         ph    Hardness       Solids  Chloramines  \
# 0                 342.0        NaN  204.890456  20791.31898     7.300212
# ...

# %% [markdown]
# ## We can come to a conclusion that from first it take 10 data from CSV File

# %%
print(df.tail(n=10))
# Out:
#       Sample ID  Temperature (°C)  Turbidity (NTU)  Dissolved Oxygen (mg/L)  \
# 3266        NaN               NaN              NaN                      NaN
# 3267        NaN               NaN              NaN                      NaN
# 3268        NaN               NaN              NaN                      NaN
# 3269        NaN               NaN              NaN                      NaN
# 3270        NaN               NaN              NaN                      NaN
# 3271        NaN               NaN              NaN                      NaN
# 3272        NaN               NaN              NaN                      NaN
# 3273        NaN               NaN              NaN                      NaN
# 3274        NaN               NaN              NaN                      NaN
# 3275        NaN               NaN              NaN                      NaN
#
#       Conductivity (µS/cm)         ph    Hardness       Solids  Chloramines  \
# ...

# %% [markdown]
# ## We can come to a conclusion that from last it take 10 data from CSV File

# %% [markdown]
# ## We can come to a conclusion boolean same-sized object indicating if the values are NA. NA values, such as None or numpy.NaN, gets mapped to True values. Everything else gets mapped to False values.

# %%
water_backup = df.copy()

# %%
missing_water_data = water_backup[water_backup.isnull().any(axis=1)]
missing_water_data
# Out:
#       Sample ID  Temperature (°C)  Turbidity (NTU)  Dissolved Oxygen (mg/L)  \
# 0           1.0              23.1              4.5                      7.8
# 1           2.0              22.3              5.1                      6.2
# 2           3.0              21.5              3.9                      8.3
# 8           9.0              20.4              4.1                      8.4
# 11         12.0              21.6              3.6                      7.1
# ...         ...               ...              ...                      ...
# 3271        NaN               NaN              NaN                      NaN
# 3272        NaN               NaN              NaN                      NaN
# 3273        NaN               NaN              NaN                      NaN
# 3274        NaN               NaN              NaN                      NaN
# 3275        NaN               NaN              NaN                      NaN
#
# ...

# %%
water_backup.describe()
# Out:
#         Sample ID  Temperature (°C)  Turbidity (NTU)  Dissolved Oxygen (mg/L)  \
# count  500.000000        500.000000       500.000000               500.000000
# mean   250.500000         22.054400         4.169400                 8.382200
# std    144.481833          0.903123         0.397492                 0.822396
# min      1.000000         20.300000         3.100000                 6.000000
# 25%    125.750000         21.200000         3.800000                 7.800000
# 50%    250.500000         22.200000         4.200000                 8.400000
# 75%    375.250000         22.900000         4.500000                 9.100000
# max    500.000000         23.600000         5.100000                 9.900000
#
#        Conductivity (µS/cm)           ph     Hardness        Solids  \
# count            500.000000  2785.000000  3276.000000   3276.000000
# mean             344.362000     7.080795   196.369496  22014.092526
# ...

# %% [markdown]
# ## We can come to a conclusion that describe of water backup in csv file

# %%
water_backup['Temperature (°C)'].mean()
# Out:
# 22.054399999999998

# %% [markdown]
# ## We can come to a conclusion that describe water's temperature mean by mean value

# %%
df['Temperature (°C)'].hist()
# Out:
# <Axes: >

# %%
df['Potability'].value_counts()
# Out:
# Potability
# 0    1998
# 1    1278
# Name: count, dtype: int64

# %%
pd.crosstab(index=water_backup['Potability'],columns='Count',dropna=True)
# Out:
# col_0       Count
# Potability
# 0            1998
# 1            1278

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.scatter(water_backup['ph'],water_backup['Temperature (°C)'], c='blue')
plt.title('Scatter plot of Ph vs Temperature (°C)')
plt.xlabel('ph')
plt.ylabel('Temperature (°C)')
# Out:
# Text(0, 0.5, 'Temperature (°C)')

# %% [markdown]
# ## We can come to a conclusion that in scatter plot we are giving ph vs temperature of water

# %%
import seaborn as sns

# %%
sns.set(style="darkgrid")
sns.regplot(x=water_backup['ph'],y=water_backup['Organic_carbon'],fit_reg=True, marker="*")
# Out:
# <Axes: xlabel='ph', ylabel='Organic_carbon'>

# %% [markdown]
# ## We can come to a conclusion that by seaborn scatterplot we are giving ph vs age of organic carbon between 6to 8 ph value is 14 organic _carbon

# %%
sns.set(style="darkgrid")
sns.regplot(x=water_backup['ph'],y=water_backup['Temperature (°C)'],fit_reg=True, marker="*")
# Out:
# <Axes: xlabel='ph', ylabel='Temperature (°C)'>

# %% [markdown]
# ## We can come to a conclusion that by seaborn scatterplot we are giving ph vs temperature in water . Drinking water has a pH range of 6.5 to 8.5 between 50 and 72 degrees Fahrenheit (10-22 degrees Celsius)

# %%
df.corr()
# Out:
#                          Sample ID  Temperature (°C)  Turbidity (NTU)  \
# Sample ID                 1.000000         -0.059358         0.118832
# Temperature (°C)         -0.059358          1.000000        -0.232663
# Turbidity (NTU)           0.118832         -0.232663         1.000000
# Dissolved Oxygen (mg/L)   0.180574          0.246976        -0.275270
# Conductivity (µS/cm)      0.184919          0.317573        -0.087372
# ph                       -0.030086          0.013581         0.032060
# Hardness                  0.002391         -0.043321        -0.018651
# Solids                   -0.029053         -0.048724         0.050171
# Chloramines               0.017114          0.018581         0.002563
# Sulfate                  -0.016579         -0.107971         0.054904
# Conductivity              0.035415          0.047270        -0.035939
# Organic_carbon            0.008943          0.031731        -0.083066
# ...

# %%
corr = df.corr()
# plot the heat map
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(corr, annot=True, ax=ax, cmap = 'coolwarm')
fig.savefig('Heat map of project.png')

# %%
water_backup.sort_index(ascending = True, axis=1)
# Out:
#            Chloramines  Conductivity  Conductivity (µS/cm)  \
# Sample ID
# 1.0           7.300212    564.308654                 342.0
# 2.0           6.635246    592.885359                 335.0
# 3.0           9.275884    418.606213                 356.0
# 4.0           8.059332    363.266516                 327.0
# 5.0           6.546600    398.410813                 352.0
# ...                ...           ...                   ...
# NaN           7.166639    526.424171                   NaN
# NaN           8.061362    392.449580                   NaN
# NaN           7.350233    432.044783                   NaN
# NaN           6.303357    402.883113                   NaN
# NaN           7.509306    327.459761                   NaN
#
#            Dissolved Oxygen (mg/L)    Hardness  Organic_carbon  Potability  \
# Sample ID
# 1.0                            7.8  204.890456       10.379783           0
# 2.0                            6.2  129.422921       15.180013           0
# ...

# %% [markdown]
# ## We can come to a conclusion that  after sorting column in ascending order

# %%
water_backup.sort_values('ph')
# Out:
#            Temperature (°C)  Turbidity (NTU)  Dissolved Oxygen (mg/L)  \
# Sample ID
# NaN                     NaN              NaN                      NaN
# NaN                     NaN              NaN                      NaN
# NaN                     NaN              NaN                      NaN
# NaN                     NaN              NaN                      NaN
# NaN                     NaN              NaN                      NaN
# ...                     ...              ...                      ...
# NaN                     NaN              NaN                      NaN
# NaN                     NaN              NaN                      NaN
# NaN                     NaN              NaN                      NaN
# NaN                     NaN              NaN                      NaN
# NaN                     NaN              NaN                      NaN
#
#            Conductivity (µS/cm)        ph    Hardness        Solids  \
# Sample ID
# ...

# %% [markdown]
# ## We can come to a conclusion that after sorting the value of ph in ascending order

# %% [markdown]
# ## We come to a conclusion that distribution of sulfate in water in the dataset. They are substances naturally present in minerals, soil and rocks. Water containing less than 500 milligrams of sulfate is safe to drink

# %%
df['Sulfate'].hist()
# Out:
# <Axes: >

# %%
df['Potability'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## We come to a conclusion that Potability column of this dataset is the column we need to predict because it contains values 0 and 1 that indicate whether the water is potable (1) or unfit (0) for consumption

# %%
Input = df.drop('Potability',axis =1)
Input
# Out:
#       Sample ID  Temperature (°C)  Turbidity (NTU)  Dissolved Oxygen (mg/L)  \
# 0           1.0              23.1              4.5                      7.8
# 1           2.0              22.3              5.1                      6.2
# 2           3.0              21.5              3.9                      8.3
# 3           4.0              22.9              3.2                      9.5
# 4           5.0              20.7              3.8                      8.1
# ...         ...               ...              ...                      ...
# 3271        NaN               NaN              NaN                      NaN
# 3272        NaN               NaN              NaN                      NaN
# 3273        NaN               NaN              NaN                      NaN
# 3274        NaN               NaN              NaN                      NaN
# 3275        NaN               NaN              NaN                      NaN
#
# ...

# %%
Output = df['Potability']
Output
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3271    1
# 3272    1
# 3273    1
# 3274    1
# 3275    1
# Name: Potability, Length: 3276, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Input, Output, test_size = 0.2, random_state=0)
